# %%
import pandas as pd

cars = pd.read_csv('../data_set/train-data.csv', index_col=0)

cars.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %% [markdown]
# **Importante**: Non convertire la valuta!!! (se no Pippo ti ammazza)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6017 non-null   object
#  8   Engine             5983 non-null   object
#  9   Power              5983 non-null   object
#  10  Seats              5977 non-null   float64
#  11  New_Price          824 non-null    object
#  12  Price              6019 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 658.3+ KB

# %%
cars['Name'].value_counts()
# Out:
# Name
# Mahindra XUV500 W8 2WD                     49
# Maruti Swift VDI                           45
# Maruti Swift Dzire VDI                     34
# Honda City 1.5 S MT                        34
# Maruti Swift VDI BSIV                      31
#                                            ..
# Tata New Safari EX 4x2                      1
# Nissan Terrano XL Plus ICC WT20 SE          1
# Honda Brio 1.2 S Option MT                  1
# Volkswagen Vento Konekt Diesel Highline     1
# Lamborghini Gallardo Coupe                  1
# Name: count, Length: 1876, dtype: int64

# %%
cars['Seats'].value_counts()
# Out:
# Seats
# 5.0     5014
# 7.0      674
# 8.0      134
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# 0.0        1
# Name: count, dtype: int64

# %%
ten_seats = cars[cars['Seats'] == 10.0]

ten_seats.head()
# Out:
#                                        Name   Location  Year  \
# 814                     Toyota Qualis FS B2       Pune  2004
# 917                            Tata Sumo DX     Mumbai  2013
# 1907                    Toyota Qualis FS B3  Bangalore  2002
# 2267                    Toyota Qualis RS E2       Pune  2004
# 2575  Chevrolet Tavera LS B3 10 Seats BSIII  Hyderabad  2015
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 814               77757    Diesel       Manual     Second   13.1 kmpl
# 917               20000    Diesel       Manual      First  14.07 kmpl
# 1907              63000    Diesel       Manual      Third   13.1 kmpl
# 2267             215750    Diesel       Manual     Second    0.0 kmpl
# 2575             120000    Diesel       Manual      First   14.8 kmpl
#
#        Engine     Power  Seats New_Price  Price
# 814   2446 CC    75 bhp   10.0       NaN   3.50
# 917   1978 CC  83.1 bhp   10.0       NaN   5.25
# ...

# %%
cars['Year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6019 entries, 0 to 6018
# Series name: Year
# Non-Null Count  Dtype
# --------------  -----
# 6019 non-null   int64
# dtypes: int64(1)
# memory usage: 94.0 KB

# %% [markdown]
# Possiamo fare inferenza per le macchine di cui non abbiao valori per i posti, considerando potenza, consumi, cilindrata, tipo di carburante etc...

# %%
cars['Location'].value_counts()
# Out:
# Location
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Ahmedabad     224
# Name: count, dtype: int64

# %%
cars['Year'].value_counts()
# Out:
# Year
# 2014    797
# 2015    744
# 2016    741
# 2013    649
# 2017    587
# 2012    580
# 2011    466
# 2010    342
# 2018    298
# 2009    198
# 2008    174
# 2007    125
# 2019    102
# 2006     78
# 2005     57
# 2004     31
# 2003     17
# 2002     15
# 2001      8
# 2000      4
# 1998      4
# 1999      2
# Name: count, dtype: int64

# %%
cars[cars['Kilometers_Driven']<1000].value_counts()
# Out:
# Name                        Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  Mileage    Engine   Power      Seats  New_Price  Price
# Maruti Wagon R ZXI AMT 1.2  Mumbai    2019  600                Petrol     Automatic     First       21.5 kmpl  1197 CC  81.80 bhp  5.0    6.8 Lakh   6.25     1
# Name: count, dtype: int64

# %%
cars['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Diesel      3205
# Petrol      2746
# CNG           56
# LPG           10
# Electric       2
# Name: count, dtype: int64

# %%
cars['Engine'] = cars['Engine'].astype(str).str.split().str[0].astype(float)

cars['Engine'].value_counts().sort_index()
# Out:
# Engine
# 72.0        1
# 624.0      25
# 793.0       4
# 796.0     129
# 799.0      36
#          ...
# 4951.0      1
# 5000.0      2
# 5204.0      1
# 5461.0      3
# 5998.0      1
# Name: count, Length: 146, dtype: int64

# %%
anomalo = cars[cars['Engine']==72.0]
anomalo
# Out:
#                       Name Location  Year  Kilometers_Driven Fuel_Type  \
# 4446  Mahindra E Verito D4  Chennai  2016              50000  Electric
#
#      Transmission Owner_Type Mileage  Engine   Power  Seats   New_Price  Price
# 4446    Automatic      First     NaN    72.0  41 bhp    5.0  13.58 Lakh   13.0

# %% [markdown]
# C'è un outlier, un auto elettrica non può avere cilindrata, non ha senso

# %%
anomali = cars[cars['Fuel_Type'] == 'Electric']
anomali
# Out:
#                            Name Location  Year  Kilometers_Driven Fuel_Type  \
# 4446       Mahindra E Verito D4  Chennai  2016              50000  Electric
# 4904  Toyota Prius 2009-2016 Z4   Mumbai  2011              44000  Electric
#
#      Transmission Owner_Type Mileage  Engine   Power  Seats   New_Price  Price
# 4446    Automatic      First     NaN    72.0  41 bhp    5.0  13.58 Lakh  13.00
# 4904    Automatic      First     NaN  1798.0  73 bhp    5.0         NaN  12.75

# %% [markdown]
# Non ha senso integrare le auto elettriche nelle analisi percheé sono molto poche
